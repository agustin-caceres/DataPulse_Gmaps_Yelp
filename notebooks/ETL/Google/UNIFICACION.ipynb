# %%
import pandas as pd
import os

# %%
g_sitios = pd.read_parquet(r'C:\Users\mauri\OneDrive\Escritorio\proyectogrupal\data\google_sitios_v2.parquet', engine='pyarrow')
g_sitios.head()
# Out:
#                                   name                             id_negocio  \
# 0  Seligman Fountain - "Bear and Faun"  0x89c2f6163ac2864f:0xa4213a2f66c15d8f
# 1                         101 Mobility   0x864c1f10c079a921:0x95710cd26231cc3
# 2           Bayrunner Fishing Charters  0x88fc79ee1ededc73:0x7003065a75ee0cf4
# 3                    JLM Manufacturing  0x8824d759c04cb37b:0xef1cb7398b3d692e
# 4              All Time Auto Transport  0x88d9050582e1e64b:0x33457ba08c64df20
#
#   description  avg_rating  num_of_reviews price  \
# 0        None         4.5               4  None
# 1        None         5.0              45  None
# 2        None         4.8              34  None
# 3        None         3.7              33  None
# 4        None         4.8              96  None
#
#                                                  url  id_estado  \
# 0  https://www.google.com/maps/place//data=!4m2!3...         13
# 1  https://www.google.com/maps/place//data=!4m2!3...          6
# ...

# %%
y_sitios = pd.read_parquet(r'C:\Users\mauri\OneDrive\Escritorio\proyectogrupal\data\yelp_business_top_5_estados.parquet', engine='pyarrow')
y_sitios.head()
# Out:
#               business_id                  name  \
# 0  n_0UpQx1hsNbnPUSlodU8w       Famous Footwear
# 1  qkRM_2X51Yqxk3btlwAQIg        Temple Beth-El
# 2  UJsufbvfyfONHeWdvAHKjA             Marshalls
# 3  jaxMSoInw8Poo3XeMJt8lQ          Adams Dental
# 4  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market
#
#                                       address            city state  \
# 0  8522 Eager Road, Dierbergs Brentwood Point       Brentwood    PA
# 1                          400 Pasadena Ave S  St. Petersburg    PA
# 2                   21705 Village Lakes Sc Dr   Land O' Lakes    FL
# 3                           15 N Missouri Ave      Clearwater    FL
# 4                               2575 E Bay Dr           Largo    FL
#
#   postal_code   latitude  longitude  stars  review_count  is_open      monday  \
# 0       63144  38.627695 -90.340465    2.5            13        1     0:0-0:0
# 1       33707  27.766590 -82.732983    3.5             5        1    9:0-17:0
# ...
